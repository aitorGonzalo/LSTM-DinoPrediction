# %%
# ==============================
# BLOCK 1: Import Libraries
# ==============================
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Embedding
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.preprocessing.sequence import pad_sequences
import random

# %%
# ==============================
# BLOCK 2: Load Dataset
# ==============================
df = pd.read_csv("dinosaur.csv") 
df.head()
# Out:
#             Name             Period       Diet        Country
# 0       Aardonyx           Jurassic  herbivore   South Africa
# 1    Abelisaurus  Cretaceous         carnivore  South America
# 2  Abrictosaurus           Jurassic  herbivore   South Africa
# 3     Abrosaurus           Jurassic  herbivore          China
# 4    Abydosaurus         Cretaceous  herbivore  North America

# %%
# ==============================
# BLOCK 3: Preprocess Names
# ==============================
df_names=df[['Name']].dropna().drop_duplicates().reset_index(drop=True)
df.head()
names=df['Name'].str.lower().tolist()
print(names)
print(len(names))
# Out:
# ['aardonyx', 'abelisaurus', 'abrictosaurus', 'abrosaurus', 'abydosaurus', 'acanthopholis', 'achelousaurus', 'acheroraptor', 'achillesaurus', 'achillobator', 'acristavus', 'acrocanthosaurus', 'acrotholus', 'adamantisaurus', 'adasaurus', 'adeopapposaurus', 'adratiklit', 'adynomosaurus', 'aegyptosaurus', 'aeolosaurus', 'aepisaurus', 'aerosteon', 'aetonyx', 'afrovenator', 'agathaumas', 'agilisaurus', 'agrosaurus', 'agujaceratops', 'agustinia', 'ahshislepelta', 'airakoraptor', 'ajkaceratops', 'akainacephalus', 'alamosaurus', 'alaskacephale', 'albalophosaurus', 'albertaceratops', 'albertadromeus', 'albertonykus', 'albertosaurus', 'albinykus', 'alcovasaurus', 'alectrosaurus', 'aletopelta', 'algoasaurus', 'alioramus', 'allosaurus', 'allosaurus', 'allosaurus', 'alnashetri', 'alocodon', 'altirhinus', 'altispinax', 'alvarezsaurus', 'alwalkeria', 'alxasaurus', 'amargasaurus', 'amargatitanis', 'amazonsaurus', 'ampelosaurus', 'amphicoelias', 'amtocephale', 'amtosaurus', 'amurosaurus', 'amygdalodon', 'anabisetia', 'anasazisaurus', 'anchiceratops', 'anchiornis', 'anchisaurus', 'andesaurus', 'angaturama', 'angolatitan', 'angulomastacator', 'aniksosaurus', 'animantarx', 'ankylosaurus', 'anodontosaurus', 'anoplosaurus', 'anserimimus', 'antarctopelta', 'antarctosaurus', 'antetonitrus', 'antrodemus', 'anzu', 'aoniraptor', 'aorun', 'apatodon', 'apatosaurus', 'appalachiosaurus', 'aquilarhinus', 'aragosaurus', 'aralosaurus', 'archaeoceratops', 'archaeodontosaurus', 'archaeopteryx', 'archaeornithoides', 'archaeornithomimus', 'arcovenator', 'arcusaurus', 'arenysaurus', 'argentinosaurus', 'argyrosaurus', 'aristosuchus', 'arkansaurus', 'arkharavia', 'arrhinoceratops', 'arstanosaurus', 'asiaceratops', 'asiatosaurus', 'astrodon', 'astrophocaudia', 'asylosaurus', 'atacamatitan', 'atlantosaurus', 'atlasaurus', 'atlascopcosaurus', 'atrociraptor', 'atsinganosaurus', 'aublysodon', 'aucasaurus', 'augustynolophus', 'auroraceratops', 'aurornis', 'australodocus', 'australovenator', 'austrocheirus', 'austroraptor', 'austrosaurus', 'avaceratops', 'aviatyrannis', 'avimimus', 'bactrosaurus', 'bagaceratops', 'bagaraatan', 'bahariasaurus', 'bainoceratops', 'bajadasaurus', 'bakesaurus', 'balaur', 'balochisaurus', 'bambiraptor', 'banji', 'baotianmansaurus', 'barapasaurus', 'barilium', 'barosaurus', 'barrosasaurus', 'barsboldia', 'baryonyx', 'batyrosaurus', 'baurutitan', 'bayosaurus', 'beelemodon', 'beipiaosaurus', 'beishanlong', 'bellusaurus', 'berberosaurus', 'betasuchus', 'bicentenaria', 'bienosaurus', 'bihariosaurus', 'bissektipelta', 'bistahieversor', 'blasisaurus', 'blikanasaurus', 'bolong', 'bonapartenykus', 'bonatitan', 'bonitasaura', 'borealosaurus', 'borogovia', 'bothriospondylus', 'brachiosaurus', 'brachyceratops', 'brachylophosaurus', 'brachypodosaurus', 'brachytrachelopan', 'bradycneme', 'brasilotitan', 'bravoceratops', 'breviceratops', 'brohisaurus', 'brontomerus', 'brontosaurus', 'bruhathkayosaurus', 'buitreraptor', 'burianosaurus', 'byronosaurus', 'caenagnathasia', 'calamosaurus', 'calamospondylus', 'callovosaurus', 'camarasaurus', 'camarillasaurus', 'camelotia', 'camposaurus', 'camptosaurus', 'campylodoniscus', 'canardia', 'capitalsaurus', 'carcharodontosaurus', 'cardiodon', 'carnotaurus', 'caseosaurus', 'cathartesaura', 'cathetosaurus', 'caudipteryx', 'cedarosaurus', 'cedarpelta', 'cedrorestes', 'centrosaurus', 'cerasinops', 'ceratonykus', 'ceratops', 'ceratosaurus', 'ceratosaurus', 'cetiosauriscus', 'cetiosaurus', 'changchunsaurus', 'changdusaurus', 'changyuraptor', 'chaoyangsaurus', 'charonosaurus', 'chasmosaurus', 'chebsaurus', 'chenanisaurus', 'chialingosaurus', 'chiayusaurus', 'chilantaisaurus', 'chilesaurus', 'chindesaurus', 'chingkankousaurus', 'chinshakiangosaurus', 'chirostenotes', 'chondrosteosaurus', 'choyrodon', 'chromogisaurus', 'chuandongocoelurus', 'chuanjiesaurus', 'chuanqilong', 'chubutisaurus', 'chungkingosaurus', 'chuxiongosaurus', 'cionodon', 'citipati', 'claorhynchus', 'claosaurus', 'clasmodosaurus', 'coahuilaceratops', 'coelophysis',  ...
# 1154

# %%
# ==============================
# BLOCK 4: Create Character Vocabulary
# ==============================
chars=sorted(list(set(''.join(names))))
char_to_idx={c:i for i,c in enumerate(chars)}
idx_to_char={i:c for i,c in enumerate(chars)}
vocab=len(chars)
print("The vocabulary contain", vocab,"characters")
# Out:
# The vocabulary contain 31 characters

# %%
# ==============================
# BLOCK 5: Prepare Sequences for LSTM
# ==============================
max_long=max(len(name)for name in names)
sequence=[]
next_chars=[]
for name in names:
    for i in range (1,len(name)):
        seq=name[:i]
        next_char=name[i]
        sequence.append([char_to_idx[j] for j in seq])
        next_chars.append(char_to_idx[next_char])

X=pad_sequences(sequence,maxlen=max_long,padding="pre")
y=to_categorical(next_chars,num_classes=vocab)

# %%
# ==============================
# BLOCK 6: Define LSTM Model
# ==============================
import keras_tuner as kt
def build_model(hp):
    model=Sequential()
    model.add(Embedding(input_dim=vocab,output_dim=hp.Int("embed_dim", min_value=32, max_value=128, step=32),input_length=max_long))
    model.add(LSTM(units=hp.Int("units",min_value=32,max_value=256,step=32),return_sequences=False))
    model.add(Dense(vocab,activation="softmax"))

    model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=hp.Choice("learning_rate",values=[1e-2, 1e-3, 1e-4])),loss="categorical_crossentropy",metrics=['accuracy'])

    return model

# %%
# ==============================
# BLOCK 7: Hyperparameter Search with Keras Tuner
# ==============================
tuner = kt.Hyperband(
    build_model,
    objective="val_accuracy",
    max_epochs=20,
    factor=3,
    directory="kt_dino",
    project_name="dino_name_gen"
)
stop_early = tf.keras.callbacks.EarlyStopping(monitor="val_loss", patience=3)
tuner.search(X,y,epochs=30, callbacks=[stop_early],validation_split=0.2)
# Out:
# Trial 26 Complete [00h 00m 25s]
# val_accuracy: 0.4683896601200104
#
# Best val_accuracy So Far: 0.4998011887073517
# Total elapsed time: 00h 19m 28s

# %%
best_hp=tuner.get_best_hyperparameters(1)[0]
best_model=tuner.hypermodel.build(best_hp)
history=best_model.fit(X,y,epochs=50,validation_split=0.2,callbacks=[stop_early],batch_size=64)
# Out:
# Epoch 1/50
# c:\Users\Agonz\LSTM-DinoPrediction\dino_env\Lib\site-packages\keras\src\layers\core\embedding.py:97: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 6s 29ms/step - accuracy: 0.3708 - loss: 2.1067 - val_accuracy: 0.4155 - val_loss: 1.9266
# Epoch 2/50
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 4s 28ms/step - accuracy: 0.4568 - loss: 1.7701 - val_accuracy: 0.4449 - val_loss: 1.8356
# Epoch 3/50
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 4s 27ms/step - accuracy: 0.4916 - loss: 1.6460 - val_accuracy: 0.4819 - val_loss: 1.7730
# Epoch 4/50
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 4s 27ms/step - accuracy: 0.5192 - loss: 1.5603 - val_accuracy: 0.4775 - val_loss: 1.7672
# Epoch 5/50
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 4s 27ms/step - accuracy: 0.5405 - loss: 1.4771 - val_accuracy: 0.4942 - val_loss: 1.7634
# Epoch 6/50
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 4s 27ms/step - accuracy: 0.5574 - loss: 1.4099 - val_accuracy: 0.4942 - val_loss: 1.7740
# Epoch 7/50
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 4s 27ms/step - accuracy: 0.5791 - loss: 1.3258 - val_accuracy: 0.4871 - val_loss: 1.8104
# Epoch 8/50
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 5s 30ms/step - accuracy: 0.5968 - loss: 1.2525 - val_accuracy: 0.4911 - val_loss: 1.8536

# %%
# ==============================
# BLOCK 8: Function to Generate Names
# ==============================
def generate_name(model, seed="", max_len=20, temperature=0.8):
    name = seed.lower()
    for _ in range(max_len):
        seq = [char_to_idx[c] for c in name if c in char_to_idx]
        seq = pad_sequences([seq], maxlen=max_len, padding='pre')
        pred = model.predict(seq, verbose=0)[0]
        pred = np.log(pred + 1e-8) / temperature      # Ajuste de temperatura
        pred = np.exp(pred) / np.sum(np.exp(pred))
        next_char_idx = np.random.choice(range(vocab), p=pred)
        next_char = idx_to_char[next_char_idx]
        if next_char == '\n':
            break
        name += next_char
    return name.capitalize()

# %%
# ==============================
# BLOCK 9: Generate Names and Compare
# ==============================

from difflib import SequenceMatcher

def similarity(a, b):
    return SequenceMatcher(None, a, b).ratio()

generated_names = []
for name in names:  
    seed = name[:2] 
    gen_name = generate_name(best_model, seed=seed, max_len=len(name))
    generated_names.append(gen_name)


print(f"{'Real Name':<20} | {'Generated Name':<20} | {'Similarity'}")
print("-"*60)
for real, gen in zip(names, generated_names):
    sim = similarity(real, gen)
    print(f"{real:<20} | {gen:<20} | {sim:.2f}")
# Out:
# Real Name            | Generated Name       | Similarity
# ------------------------------------------------------------
# aardonyx             | Aatasaurus           | 0.33
# abelisaurus          | Abudiasaurusa        | 0.58
# abrictosaurus        | Abropcosauruste      | 0.71
# abrosaurus           | Abrariasauru         | 0.64
# abydosaurus          | Abrosaurustas        | 0.67
# acanthopholis        | Acasaurusaurusa      | 0.21
# achelousaurus        | Achagosaurusaur      | 0.64
# acheroraptor         | Acrosaurusauru       | 0.46
# achillesaurus        | Acroceratopsasa      | 0.29
# achillobator         | Acroraptorsaur       | 0.31
# acristavus           | Acrahalosaur         | 0.45
# acrocanthosaurus     | Achyorasaurusaurus   | 0.41
# acrotholus           | Achyprosauru         | 0.36
# adamantisaurus       | Adistesaurusauru     | 0.53
# adasaurus            | Adallypanpo          | 0.30
# adeopapposaurus      | Adrosposmocusauru    | 0.56
# adratiklit           | Adesaurusaur         | 0.27
# adynomosaurus        | Adroodontosauru      | 0.57
# aegyptosaurus        | Aeustryphosauru      | 0.64
# aeolosaurus          | Aeumaisaurusa        | 0.58
# aepisaurus           | Aevusaurusau         | 0.64
# aerosteon            | Aecrisaurus          | 0.30
# aetonyx              | Aepeltas4            | 0.12
# afrovenator          | Afuilanasauru        | 0.33
# agathaumas           | Agujsusaurus         | 0.36
# agilisaurus          | Agraviceppanp        | 0.25
# agrosaurus           | Agrosaurusau         | 0.82
# agujaceratops        | Aghulvusaurusau      | 0.21
# agustinia            | Agninasauru          | 0.40
# ahshislepelta        | Ahantanorapposa      | 0.21
# airakoraptor         | Aigaraptorapto       | 0.69
# ajkaceratops         | Ajuesaurusauru       | 0.23
# akainacephalus       | Akevusaurusaurus     | 0.27
# alamosaurus          | Albyrosaurust        | 0.67
# alaskacephale        | Albertanusaurus      | 0.21
# albalophosaurus      | Albirhinosaurusau    | 0.62
# albertaceratops      | Allisaurusaurusau    | 0.31
# albertadromeus       | Albisaurusaurusa     | 0.33
# albertonykus         | Altisaurusauru       | 0.31
# albertosaurus        | Albaraptorexias      | 0.43
# albinykus            | Allasaurusa          | 0.30
# alcovasaurus         | Aldoabersovena       | 0.31
# alectrosaurus        | Alichasaurussus      | 0.50
# aletopelta           | Alicanthosau         | 0.36
# algoasaurus          | Alkerasaurust        | 0.67
# alioramus            | Aldisaurusa          | 0.40
# allosaurus           | Allisaurusau         | 0.73
# allosaurus           | Albesaurusau         | 0.64
# allosaurus           | Altisaurusau         | 0.64
# alnashetri           | Alestesaurus         | 0.18
# alocodon             | Alecusauru           | 0.11
# altirhinus           | Alkasaurusau         | 0.36
# altispinax           | Alheusaurusa         | 0.27
# alvarezsaurus        | Aldisaurusaurus      | 0.50
# alwalkeria           | Albatitasaur         | 0.27
# alxasaurus           | Alalialisaur         | 0.64
# amargasaurus         | Amkayusaurusau       | 0.54
# amargatitanis        | Amastasaurusaur      | 0.36
# amazonsaurus         | Amaeriasaurust       | 0.62
# ampelosaurus         | Amplusaurusaur       | 0.69
# amphicoelias         | Ampsaurusaurus       | 0.31
# amtocephale          | Amagasaurusau        | 0.17
# amtosaurus           | Amasaurusaur         | 0.64
# amurosaurus          | Amiangiuquans        | 0.25
# amygdalodon          | Amonychusauru        | 0.25
# anabisetia           | Angosaurusau         | 0.18
# anasazisaurus        | Ancharosaurusau      | 0.50
# anchiceratops        | Anaciatitantius      | 0.29
# anchiornis           | Anlochusauru         | 0.36
# anchisaurus          | Anzocephalosa        | 0.25
# andesaurus           | Antabusaurus         | 0.64
# angaturama           | Anuropsusaur         | 0.36
# angolatitan          | Ankasaurusaur        | 0.25
# angulomastacator     | Animpsasaurusaurus   | 0.41
# aniksosaurus         | Antosaurusauru       | 0.62
# animantarx           | Angyangosaur         | 0.36
# ankylosaurus         | Andusasauruste       | 0.54
# anodontosaurus       | Anecatosaurusaur     | 0.60
# anoplosaurus         | Ancharrasaurus       | 0.54
# anserimimus          | Antarosaurusa        | 0.42
# antarctopelta        | Anchianptosauru      | 0.36
# antarctosaurus       | Anchodontosaurus     | 0.67
# antetonitrus         | Annisaurusauru       | 0.46
# antrodemus           | Anchyrosauru         | 0.36
# anzu                 | Antari               | 0.20
# aoniraptor           | Aodomasbatos         | 0.36
# aorun                | Aongosa              | 0.17
# apatodon             | Apatopsaur           | 0.44
# apatosaurus          | Apatosaurusau        | 0.83
# appalachiosaurus     | Apratoratusaurusau   | 0.47
# aquilarhinus         | Aquilosaurusau       | 0.62
# aragosaurus          | Archaousaurus        | 0.67
# aralosaurus          | Aranosaurusau        | 0.75
# archaeoceratops      | Arkusivocusaurusa    | 0.31
# archaeodontosaurus   | Armiantosaurusaurusa | 0.53
# archaeopteryx        | Archaeopeltasau      | 0.57
# archaeornithoides    | Aragousaurusaurusau  | 0.28
# archaeornithomimus   | Arasaurusaurusaurusa | 0.21
# arcovenator          | Archaeosaurus        | 0.42
# arcusaurus           | Arkantinosau         | 0.36
# arenysaurus          | Archasaurasau        | 0.50
# argentinosaurus      | Arcatoraptorsauru    | 0.56
# argyrosaurus         | Archabbosaurus       | 0.62
# aristosuchus         | Arharhaysaurus       | 0.46
# arkansaurus          | Argocephalesa        | 0.25
# arkharavia           | Arcolestesau         | 0.09
# arrhinoceratops      | Archagosaurusauru    | 0.19
# arstanosaurus        | Arunosaurusauru      | 0.64
# asiaceratops         | Astrodonusauru       | 0.15
# asiatosaurus         | Aselosaurusaur       | 0.62
# astrodon             | Ashasaurus           | 0.33
# astrophocaudia       | Aschicephalosaur     | 0.40
# asylosaurus          | Asasaurusauru        | 0.58
# atacamatitan         | Athagosauruste       | 0.15
# atlantosaurus        | Atrasaurusaurus      | 0.50
# atlasaurus           | Atriamasauru         | 0.64
# atlascopcosaurus     | Atarphysaurusaurus   | 0.47
# atrociraptor         | Atraptoriasaur       | 0.54
# atsinganosaurus      | Atadonimusaurusau    | 0.50
# aublysodon           | Austrophopsi         | 0.36
# aucasaurus           | Austrosaurus         | 0.64
# augustynolophus      | Austrophasaurusau    | 0.50
# auroraceratops       | Austroraptorsaur     | 0.53
# aurornis             | Ausmimusau           | 0.22
# australodocus        | Auropsaurusauru      | 0.36
# australovenator      | Australosaurusaur    | 0.56
# austrocheirus        | Auronopsusaurus      | 0.36
# austroraptor         | Austropholeste       | 0.54
# austrosaurus         | Austropstetita       | 0.54
# avaceratops          | Avactiraptors        | 0.67
# aviatyrannis         | Avachtosaurusa       | 0.31
# avimimus             | Aviopantos           | 0.33
# bactrosaurus         | Baronykusaurus       | 0.69
# bagaceratops         | Barnosaurusaur       | 0.31
# bagaraatan           | Baraviasauru         | 0.45
# bahariasaurus        | Barchacephalesa      | 0.43
# bainoceratops        | Baravimatosauru      | 0.43
# bajadasaurus         | Barasavontasau       | 0.46
# bakesaurus           | Baralosauras         | 0.55
# balaur               | Barosaur             | 0.57
# balochisaurus        | Barapasaurusaur      | 0.50
# bambiraptor          | Barivenatorax        | 0.50
# banji                | Balasau              | 0.17
# baotianmansaurus     | Balaraptorenmiausa   | 0.35
# barapasaurus         | Bardyodontousa       | 0.31
# barilium             | Barnisauru           | 0.44
# barosaurus           | Balapisaurus         | 0.64
# barrosasaurus        | Bardusaurusauru      | 0.57
# barsboldia           | Balamosaurus         | 0.27
# baryonyx             | Bataptosau           | 0.22
# batyrosaurus         | Balabasaurusau       | 0.62
# baurutitan           | Barrheusauru         | 0.36
# bayosaurus           | Balasaurusau         | 0.64
# beelemodon           | Beroceratops         | 0.27
# beipiaosaurus        | Belbertasaurusa      | 0.64
# beishanlong          | Beloraptorsau        | 0.25
# bellusaurus          | Berasaurusaur        | 0.58
# berberosaurus        | Berotasaurusaur      | 0.64
# betasuchus           | Bentrorasaur         | 0.45
# bicentenaria         | Biavlarasaurus       | 0.31
# bienosaurus          | Bilapallasaur        | 0.42
# bihariosaurus        | Bishasaurusauru      | 0.64
# bissektipelta        | Bishanosaurusau      | 0.29
# bistahieversor       | Bilahalasaurusau     | 0.33
# blasisaurus          | Blarognathusa        | 0.33
# blikanasaurus        | Blicatosaurusau      | 0.64
# bolong               | Bochisau             | 0.14
# bonapartenykus       | Bopachycnosaurus     | 0.40
# bonatitan            | Boabrusauru          | 0.20
# bonitasaura          | Bohalacephusa        | 0.33
# borealosaurus        | Boricharnasauru      | 0.57
# borogovia            | Bolbodesumi          | 0.30
# bothriospondylus     | Bolarhadisaurusaur   | 0.29
# brachiosaurus        | Brachylophosaur      | 0.64
# brachyceratops       | Brachypsaurusaur     | 0.47
# brachylophosaurus    | Brushanosaurusaurus  | 0.50
# brachypodosaurus     | Brachyphosaurustes   | 0.76
# brachytrachelopan    | Bracosaurusaurusaur  | 0.33
# bradycneme           | Brachyyrusau         | 0.27
# brasilotitan         | Brichaeusaurus       | 0.31
# bravoceratops        | Brachyponyxosau      | 0.29
# breviceratops        | Brachylophosaur      | 0.36
# brohisaurus          | Brachypstespo        | 0.17
# brontomerus          | Brobilaysauru        | 0.33
# brontosaurus         | Bracosaurusaur       | 0.62
# bruhathkayosaurus    | Bratnopsaurusaurust  | 0.56
# buitreraptor         | Buyshansaurusa       | 0.23
# burianosaurus        | Burotitanusauru      | 0.71
# byronosaurus         | Bythrosauruste       | 0.69
# caenagnathasia       | Caterosaurusauru     | 0.33
# calamosaurus         | Calatitanasaur       | 0.54
# calamospondylus      | Calasaurusaurusau    | 0.38
# callovosaurus        | Cauppatoraptora      | 0.21
# camarasaurus         | Carhodontosaur       | 0.46
# camarillasaurus      | Camaraptoralosaur    | 0.56
# camelotia            | Carkosaurus          | 0.30
# camposaurus          | Camarasaurasa        | 0.58
# camptosaurus         | Camarasaurusau       | 0.62
# campylodoniscus      | Carchaeopeltasaur    | 0.38
# canardia             | Campsasaur           | 0.33
# capitalsaurus        | Carchasrasaurus      | 0.64
# carcharodontosaurus  | Cacariosaurusaurusaur | 0.50
# cardiodon            | Camalalatho          | 0.20
# carnotaurus          | Carchaeoptery        | 0.42
# caseosaurus          | Calaraptoryxo        | 0.25
# cathartesaura        | Castrosaurustes      | 0.50
# cathetosaurus        | Carhardosaurusa      | 0.64
# caudipteryx          | Calbosaurusau        | 0.25
# cedarosaurus         | Cerythantisaur       | 0.46
# cedarpelta           | Ceromadisaur         | 0.36
# cedrorestes          | Ceracotopelta        | 0.25
# centrosaurus         | Ceratosaurusau       | 0.69
# cerasinops           | Ceratasaurus         | 0.45
# ceratonykus          | Ceratosaurusa        | 0.58
# ceratops             | Cedrosauru           | 0.33
# ceratosaurus         | Cerceratopsisa       | 0.62
# ceratosaurus         | Cerosaurusauru       | 0.69
# cetiosauriscus       | Ceratosaurusauru     | 0.60
# cetiosaurus          | Centrosaurusa        | 0.75
# changchunsaurus      | Chaeosaurusaurusa    | 0.50
# changdusaurus        | Chuanosaurusaur      | 0.64
# changyuraptor        | Chasgocephusaur      | 0.36
# chaoyangsaurus       | Chachyplopusauru     | 0.53
# charonosaurus        | Chicrappodontop      | 0.36
# chasmosaurus         | Chubengosaurus       | 0.62
# chebsaurus           | Chitanisauru         | 0.55
# chenanisaurus        | Childexasaurusa      | 0.64
# chialingosaurus      | Chubeosaurusaurus    | 0.50
# chiayusaurus         | Churisaurusaur       | 0.62
# chilantaisaurus      | Chaeocephalosauru    | 0.50
# chilesaurus          | Chiskanosauru        | 0.58
# chindesaurus         | Chontrosaurusa       | 0.62
# chingkankousaurus    | Chonopteryxodonmong  | 0.17
# chinshakiangosaurus  | Chariamiausaurusaurus | 0.50
# chirostenotes        | Chalosaurusauru      | 0.29
# chondrosteosaurus    | Chistesaurusaurusau  | 0.56
# choyrodon            | Chetodontos          | 0.50
# chromogisaurus       | Chastasaurusauru     | 0.47
# chuandongocoelurus   | Chalamosaurusaurusau | 0.37
# chuanjiesaurus       | Chinzhousaurusau     | 0.53
# chuanqilong          | Chasosaurusau        | 0.25
# chubutisaurus        | Chischarosaurus      | 0.57
# chungkingosaurus     | Chiotiniasaurusaur   | 0.53
# chuxiongosaurus      | Chabatitansaurusa    | 0.56
# cionodon             | Cishansaur           | 0.22
# citipati             | Citasaurus           | 0.33
# claorhynchus         | Clangoausaurus       | 0.38
# claosaurus           | Clastaopusau         | 0.55
# clasmodosaurus       | Clashosaurusauru     | 0.67
# coahuilaceratops     | Cosksypsosaurusaur   | 0.18
# coelophysis          | Conaspacephal        | 0.33
# coelophysis          | Coevenasaurus        | 0.33
# coelosaurus          | Costryphaceph        | 0.25
# coeluroides          | Coenopteryxos        | 0.42
# coelurus             | Coeluasaur           | 0.56
# colepiocephale       | Cotrosaurusaurus     | 0.20
# coloradisaurus       | Corcharasaurusau     | 0.60
# comahuesaurus        | Copparcolasauru      | 0.57
# comanchesaurus       | Colamensaurusaur     | 0.60
# compsognathus        | Coerraptoraptor      | 0.36
# compsosuchus         | Comarisaurusau       | 0.46
# concavenator         | Cordodontosaur       | 0.38
# conchoraptor         | Congopasaurusa       | 0.38
# condorraptor         | Colaphaupstesa       | 0.31
# coronosaurus         | Cosklosaurusau       | 0.62
# corythosaurus        | Compsosaurusaur      | 0.57
# craspedodon          | Cratherosauru        | 0.25
# craterosaurus        | Craaceratopsaur      | 0.64
# crichtonpelta        | Cruslanosaurusa      | 0.21
# crichtonsaurus       | Cracovasaurusaur     | 0.53
# cristatusaurus       | Crusucausaurusau     | 0.60
# cruxicheiros         | Crasodontopelt       | 0.15
# cryolophosaurus      | Crachyptosaurusau    | 0.62
# cryptosaurus         | Criotasaurusau       | 0.62
# cumnoria             | Curasaurus           | 0.33
# daanosaurus          | Damalatitanus        | 0.42
# dacentrurus          | Daemasaurusau        | 0.50
# dachongosaurus       | Daktasaurausauru     | 0.40
# daemonosaurus        | Dashansaurusaur      | 0.57
# dahalokely           | Dasosaurusti         | 0.18
# dakotadon            | Daenasaurus          | 0.20
# dakotaraptor         | Datzacephalosa       | 0.23
# damalasaurus         | Dalophasaurusa       | 0.69
# dandakosaurus        | Dayalosaurusaur      | 0.64
# darwinsaurus         | Dasesaurusauru       | 0.54
# dashanpusaurus       | Dathagosaurustes     | 0.60
# daspletosaurus       | Dashansaurasauru     | 0.47
# datanglong           | Dahosaurusau         | 0.18
# datousaurus          | Dahirosaurusa        | 0.67
# daxiatitan           | Darphaausaur         | 0.27
# deinocheirus         | Deinomimosauru       | 0.54
# deinodon             | Deinosauru           | 0.44
# deinonychus          | Dearralosauru        | 0.25
# deinonychus          | Deinosaurusau        | 0.50
# delapparentia        | Delosaurustesau      | 0.29
# deltadromeus         | Dekmiceratop0e       | 0.31
# demandasaurus        | Delosaurusaurus      | 0.50
# diabloceratops       | Dikraceratopsaur     | 0.67
# diamantinasaurus     | Dihangiavracusauru   | 0.47
# diclonius            | Dicergosaur          | 0.40
# dicraeosaurus        | Dilophusaurusau      | 0.57
# dilong               | Diamusau             | 0.14
# dilophosaurus        | Dilarosaurusaur      | 0.64
# diluvicursor         | Diatyrannosaur       | 0.23
# dinheirosaurus       | Dinyangosaurusau     | 0.60
# dinodocus            | Dilocharosa          | 0.40
# diplodocus           | Dinkroplocep         | 0.45
# diplotomodon         | Dilongosaurusa       | 0.31
# dolichosuchus        | Donidongosaurus      | 0.50
# dongbeititan         | Doshandosaurus       | 0.23
# dongyangopelta       | Domasaurusaurusa     | 0.20
# dongyangosaurus      | Doetisaurusaurusa    | 0.44
# draconyx             | Dryphasaur           | 0.22
# dracopelta           | Drocatorapto         | 0.27
# dracoraptor          | Drophosaurusa        | 0.33
# dracorex             | Dravosauru           | 0.44
# dracovenator         | Drotyranisauru       | 0.38
# dreadnoughtus        | Drachovisaurusa      | 0.43
# drinker              | Drachydos            | 0.12
# dromaeosauroides     | Dromaeosaurusaurus   | 0.65
# dromaeosaurus        | Drinosaurusauru      | 0.57
# dromiceiomimus       | Dracosaurusaurus     | 0.27
# drusilasaura         | Drachypsaurust       | 0.46
# dryosaurus           | Drachakiabus         | 0.36
# dryosaurus           | Droconthodon         | 0.18
# dryptosauroides      | Dromaeopsaurusaur    | 0.44
# dryptosaurus         | Drachasaurusau       | 0.54
# dubreuillosaurus     | Durostesaurusaurus   | 0.53
# duriatitan           | Durosauruste         | 0.36
# duriavenator         | Duhyonodontosa       | 0.31
# dynamoterror         | Dyslorosaurusa       | 0.38
# dyoplosaurus         | Dysganasaurusa       | 0.54
# dysalotosaurus       | Dyklosaurusaur4u     | 0.60
# dysganus             | Dysmolopso           | 0.33
# dyslocosaurus        | Dysatasaurusaur      | 0.57
# dystrophaeus         | Dyroplasauru4a       | 0.46
# echinodon            | Echetosauru          | 0.30
# edmontonia           | Edmondosauru         | 0.55
# edmontosaurus        | Edmolophocerato      | 0.36
# efraasia             | Efraptodon           | 0.33
# einiosaurus          | Eimosaurusaur        | 0.67
# ek troodont          | Ekrisaurusaur        | 0.17
# ekrixinatosaurus     | Ekonykasaurusaurus   | 0.53
# elaltitan            | Elasaurusau          | 0.30
# elaphrosaurus        | Elsampavusaurus      | 0.64
# elmisaurus           | Elevusaurusu         | 0.64
# elopteryx            | Elmasaurusa          | 0.20
# elrhazosaurus        | Elydenodonsauru      | 0.50
# emausaurus           | Emphiausauru         | 0.73
# enigmosaurus         | Enarpiavenatos       | 0.31
# eoabelisaurus        | Eocirhivusaurus      | 0.57
# eocarcharia          | Eoyangosaurus        | 0.25
# eocursor             | Eoceratops           | 0.44
# eodromaeus           | Eosaurusauru         | 0.36
# eolambia             | Eorhosauru           | 0.22
# eomamenchisaurus     | Eostryphusaurusaur   | 0.47
# eoraptor             | Eocharhita           | 0.33
# eosinopteryx         | Eocatoraptorsa       | 0.38
# eotrachodon          | Eomaxusaurusa        | 0.25
# eotriceratops        | Eolosaurusaurus      | 0.29
# eotyrannus           | Eomaydosauru         | 0.36
# eousdryosaurus       | Eopterosaurusaur     | 0.60
# epachthosaurus       | Episaurusaurusau     | 0.47
# epanterias           | Epimastasaur         | 0.36
# epichirostenotes     | Epidomimusaurusaur   | 0.29
# epidendrosaurus      | Episteiodesmosaur    | 0.56
# epidexipteryx        | Eptiasaurusauru      | 0.21
# equijubus            | Equantansau          | 0.30
# erectopus            | Ergiosaurus          | 0.40
# erketu               | Erliasau             | 0.29
# erliansaurus         | Erkosaurustesm       | 0.54
# erlikosaurus         | Erihasaurusaur       | 0.62
# eshanosaurus         | Eseleranmianas       | 0.31
# eucamerotus          | Eucnkosaurusa        | 0.50
# eucercosaurus        | Eurongkusaurusa      | 0.64
# eucnemesaurus        | Eumanasaurusaur      | 0.57
# eugongbusaurus       | Eucustryphosauru     | 0.47
# euhelopus            | Europteryxo          | 0.30
# euoplocephalus       | Eucelosaurusauru     | 0.40
# euronychodon         | Eurostexocusau       | 0.31
# europasaurus         | Eumpsosaurusau       | 0.62
# europatitan          | Eustriosaurus        | 0.17
# europelta            | Eucantonpel          | 0.50
# euskelosaurus        | Eucneocephalosa      | 0.43
# eustreptospondylus   | Eucavosaurusaurusaur | 0.26
# fabrosaurus          | Facrosaurusta        | 0.75
# falcarius            | Fangganasau          | 0.30
# ferganasaurus        | Fenchysaurasaur      | 0.50
# ferganocephale       | Ferrithopusaurus     | 0.20
# ferrisaurus          | Ferrhosaurust        | 0.75
# fostoria             | Fontarkusa           | 0.33
# fruitadens           | Frachognathu         | 0.18
# fukuiraptor          | Fukuilapussau        | 0.50
# fukuisaurus          | Fushanusaurus        | 0.67
# fukuititan           | Fustakusauru         | 0.36
# fukuivenator         | Fukuitaiaurasa       | 0.46
# fulengia             | Fukuiaurus           | 0.33
# fulgurotherium       | Fushalosaurusaur     | 0.33
# fushanosaurus        | Fukalisaurusaur      | 0.57
# fusuisaurus          | Fusutaxasauru        | 0.67
# futabasaurus         | Fusaurusaurust       | 0.54
# futalognkosaurus     | Fulastasauravusaur   | 0.53
# gadolosaurus         | Gadycnatitasau       | 0.38
# galeamopus           | Garaptorsaur         | 0.36
# galleonosaurus       | Gaclophocephalus     | 0.27
# gallimimus           | Gajasaurusau         | 0.27
# galvesaurus          | Ganocephalest        | 0.33
# gannansaurus         | Galasosaurusau       | 0.62
# ganzhousaurus        | Galeskesaurusau      | 0.50
# gargoyleosaurus      | Gabusaurusaurusau    | 0.44
# garudimimus          | Gamantosaurus        | 0.33
# gasosaurus           | Garosauruste         | 0.73
# gasparinisaura       | Gapalasaurusauru     | 0.53
# gastonia             | Gachypsaur           | 0.33
# geminiraptor         | Gepatitasaurus       | 0.23
# genusaurus           | Gencasaurusa         | 0.73
# genyodectes          | Geinosaurusau        | 0.33
# geranosaurus         | Geriasaurusaur       | 0.69
# gideonmantellia      | Ginanosaurusaurus    | 0.31
# giganotosaurus       | Giheysaurusaurus     | 0.47
# gigantoraptor        | Giylosaurusauru      | 0.36
# gigantosaurus        | Giloceratopsisa      | 0.43
# gigantspinosaurus    | Gitraptoraptorsauru  | 0.56
# gilmoreosaurus       | Gianosaurusaurus     | 0.53
# giraffatitan         | Gitrasaurusaur       | 0.38
# glacialisaurus       | Glacosaurusterus     | 0.60
# glishades            | Glacephalos          | 0.40
# glyptodontopelta     | Glanoceratopsaurus   | 0.35
# gnathovorax          | Gnatrocephali        | 0.42
# gobiceratops         | Gochrophosauru       | 0.46
# gobiraptor           | Golmarhasaur         | 0.36
# gobisaurus           | Gonosaurusau         | 0.64
# gobititan            | Gonisgusaur          | 0.20
# gobivenator          | Gobilochosaur        | 0.42
# gojirasaurus         | Gongosaurusaur       | 0.62
# gondwanatitan        | Gobithosaurusau      | 0.29
# gongbusaurus         | Gocachyodontop       | 0.15
# gongpoquansaurus     | Gojocephalosaurusa   | 0.53
# gongxianosaurus      | Gobrocoraptorsaur    | 0.44
# gorgosaurus          | Goplosaurusau        | 0.67
# goyocephale          | Godongosaurus        | 0.25
# graciliceratops      | Grachiasaurusauru    | 0.38
# graciliraptor        | Gracosaurusauru      | 0.43
# gravitholus          | Gramosaurusau        | 0.42
# gryphoceratops       | Grachytosaurusau     | 0.33
# gryposaurus          | Gryposaurusau        | 0.83
# gspsaurus            | Gsecasaurus          | 0.70
# guaibasaurus         | Guropasaurusau       | 0.62
# gualicho             | Gurontosau           | 0.22
# guanlong             | Gurodontos           | 0.33
# gyposaurus           | Gyposaurusbe         | 0.82
# gyposaurus           | Gyburasaurus         | 0.64
# hadrosaurus          | Hanzhosaurusa        | 0.67
# hagryphus            | Halepsaurus          | 0.40
# halticosaurus        | Haplosaurusauru      | 0.64
# hanssuesia           | Hanterasaura         | 0.45
# hanwulosaurus        | Hamarptopeltali      | 0.21
# haplocanthosaurus    | Hasteisaurusaurusus  | 0.44
# haplocheirus         | Halamenasaurus       | 0.46
# harpymimus           | Hadistasauru         | 0.27
# haya                 | Hagasa               | 0.40
# heilongjiangosaurus  | Heubutilasaurusaurusa | 0.50
# heishansaurus        | Hepusaurusaurus      | 0.50
# helioceratops        | Hespsaurusaurus      | 0.21
# heptasteornis        | Heurosaurustesi      | 0.43
# herrerasaurus        | Hercosaurusauru      | 0.57
# hesperonychus        | Henningosaurusa      | 0.36
# hesperosaurus        | Hepachyphasauru      | 0.50
# heterodontosaurus    | Herasaurusaurusauru  | 0.44
# hexing               | Henisaur             | 0.29
# hexinlusaurus        | Herapatorasauru      | 0.43
# heyuannia            | Hepsaurusau          | 0.30
# hippodraco           | Hilongosauru         | 0.27
# histriasaurus        | Hilophysisaurus      | 0.57
# homalocephale        | Homahalachasaur      | 0.43
# hoplitosaurus        | Holarhapalasaur      | 0.50
# horshamosaurus       | Hophovenatorasau     | 0.47
# huabeisaurus         | Hurinodontusau       | 0.38
# huanghetitan         | Huxiasaurusaur       | 0.23
# huaxiagnathus        | Hugilosaurusaur      | 0.29
# huayangosaurus       | Hursaurusauruste     | 0.47
# hudiesaurus          | Huahanthosaur        | 0.42
# huehuecanauhtlus     | Huwusaurusaurusaur   | 0.35
# hulsanpes            | Huntarusaur          | 0.30
# hungarosaurus        | Hungkysaurusaur      | 0.64
# huxleysaurus         | Huyrianosaurus       | 0.62
# hylaeosaurus         | Hypsodontosaur       | 0.46
# hypacrosaurus        | Hyptoryxiasaur1      | 0.50
# hypselosaurus        | Hyplophosaurus0      | 0.71
# hypselospinus        | Hypyocephalosa       | 0.43
# hypsibema            | Hypsosaurus          | 0.40
# hypsilophodon        | Hypsodontopelta      | 0.50
# ichthyovenator       | Icriophasaurusau     | 0.27
# ignavusaurus         | Igankhosaurusa       | 0.62
# iguanacolossus       | Igantosaurusauru     | 0.47
# iguanodon            | Igmantosaur          | 0.40
# iliosuchus           | Ilvursodonto         | 0.18
# ilokelesia           | Illasaurusau         | 0.36
# imperobator          | Imysaurusauru        | 0.33
# incisivosaurus       | Inosaurusaurusau     | 0.53
# indosaurus           | Ingrosaurusa         | 0.73
# indosuchus           | Inoplosaurus         | 0.55
# inosaurus            | Inkanosauru          | 0.70
# irritator            | Irischusaur          | 0.40
# isaberrysaura        | Ischasaurusauru      | 0.50
# isanosaurus          | Isaurusaurusa        | 0.50
# ischyrosaurus        | Ischuvexasaurus      | 0.64
# isisaurus            | Ishasaurusa          | 0.70
# itapeuasaurus        | Itriaiaurusauru      | 0.57
# itemirus             | Itosaurusa           | 0.44
# iuticosaurus         | Iubasaurusauru       | 0.54
# jainosaurus          | Jasaopposauru        | 0.58
# jaklapallisaurus     | Jaarkiasaurusaurus   | 0.53
# janenschia           | Jaanganusaur         | 0.45
# jaxartosaurus        | Jaanzhosaurusau      | 0.64
# jeholosaurus         | Jesangosaurusa       | 0.62
# jeyawati             | Jegyptos0o           | 0.33
# jianchangosaurus     | Jiangsaurusaurusau   | 0.59
# jiangjunosaurus      | Jianggnasaurusaur    | 0.69
# jiangshanosaurus     | Jiadelloelusaurusa   | 0.53
# jiangxisaurus        | Jianosaurusauru      | 0.64
# jinfengopteryx       | Jiakosaurusaurus     | 0.20
# jingshanosaurus      | Jianchanosaurusau    | 0.75
# jintasaurus          | Jianchaurusau        | 0.58
# jinzhousaurus        | Jiancaurasaurus      | 0.64
# jiutaisaurus         | Jianpanasaurus       | 0.62
# jobaria              | Jotanpelt            | 0.25
# jubbulpuria          | Juangnisaurus        | 0.25
# judiceratops         | Juetasaurusaur       | 0.31
# juratyrant           | Jurkyrnasaur         | 0.45
# juravenator          | Juebusaurus4u        | 0.17
# kaatedocus           | Kaevosaurusa         | 0.36
# kaijiangosaurus      | Kaybsaurusaurusau    | 0.44
# kakuru               | Kaisauru             | 0.57
# kamuysaurus          | Kalapisaurusa        | 0.58
# kangnasaurus         | Karshamodontos       | 0.23
# karongasaurus        | Karchasusaurusa      | 0.64
# katepensaurus        | Kaniasaurusauru      | 0.57
# kayentavenator       | Kapiganatosaurus     | 0.47
# kazaklambia          | Kansaurusauru        | 0.25
# kelmayisaurus        | Kektinosaurusau      | 0.57
# kentrosaurus         | Ketnavusaurusa       | 0.62
# kerberosaurus        | Keraceratopsaud      | 0.57
# khaan                | Khuabsa              | 0.50
# khetranisaurus       | Khotilanthosauru     | 0.60
# kileskus             | Kialisauru           | 0.44
# kinnareemimus        | Kistadusaurusau      | 0.29
# klamelisaurus        | Klitavocusaurus      | 0.57
# kol                  | Kolop                | 0.50
# koparion             | Konchaeosa           | 0.22
# koreaceratops        | Koryohadontopel      | 0.43
# koreanosaurus        | Konosaurusaurus      | 0.64
# koreanosaurus        | Koelosaurusauru      | 0.64
# koshisaurus          | Kolaraptorato        | 0.25
# kosmoceratops        | Korharasaurusau      | 0.29
# kotasaurus           | Koelosaurusa         | 0.64
# kritosaurus          | Krathophosaur        | 0.58
# kryptops             | Krosasauru           | 0.33
# kukufeldia           | Kuehuengosau         | 0.36
# kulceratops          | Kurectitantho        | 0.42
# kulindadromeus       | Kubianchosaurusa     | 0.47
# kunbarrasaurus       | Kunheliadrosauru     | 0.60
# kundurosaurus        | Kundupnosaurusa      | 0.79
# kunmingosaurus       | Kurbusaurusaurus     | 0.47
# labocania            | Laspasaurus          | 0.30
# laevisuchus          | Laevusaurusau        | 0.42
# lajasvenator         | Lapatosauruste       | 0.38
# lamaceratops         | Lapporaptorsas       | 0.46
# lambeosaurus         | Lasmasusaurust       | 0.62
# lametasaurus         | Lavisaurustesm       | 0.54
# lamplughsaura        | Laevusaurusauru      | 0.50
# lancanjiangosaurus   | Laatiosaurusaurusaur | 0.53
# lanzhousaurus        | Laklamimosaurus      | 0.64
# laosaurus            | Lalbaraptor          | 0.40
# lapampasaurus        | Laspaceratopsau      | 0.50
# laplatasaurus        | Larchaeocephale      | 0.07
# lapparentosaurus     | Layasaurusaurusaur   | 0.47
# laquintasaura        | Lasthodontousau      | 0.43
# latenivenatrix       | Lapsosaurustesis     | 0.27
# latirhinus           | Lasteirosaur         | 0.45
# leaellynasaura       | Leanosaurusaurus     | 0.53
# leinkupal            | Lekrasaurus          | 0.30
# leonerasaurus        | Levachasaurusau      | 0.57
# leptoceratops        | Legasaurusaurus      | 0.29
# leptorhynchos        | Lecantosaurusau      | 0.36
# leshansaurus         | Leucnosaurusau       | 0.62
# lesothosaurus        | Leshanraptorsau      | 0.43
# lessemsaurus         | Lemevenatoralj       | 0.31
# levnesovia           | Levacopsauru         | 0.36
# lexovisaurus         | Lessaurusaurus       | 0.54
# leyesaurus           | Lekuanasauru         | 0.55
# liaoceratops         | Liangweusaurus       | 0.38
# liaoningosaurus      | Liraptoraptorsaur    | 0.50
# liassaurus           | Libertiasaur         | 0.55
# ligabueino           | Lisosaurusau         | 0.27
# ligabuesaurus        | Lishanosaurusau      | 0.57
# lihkoelesauus        | Liangosaurustes      | 0.50
# liliensternus        | Lispausaurusaur      | 0.29
# limaysaurus          | Lisatisaurusa        | 0.67
# limusaurus           | Lichoraptory         | 0.27
# lingwulong           | Licosaurusau         | 0.18
# linhenykus           | Liosaurusaur         | 0.27
# linheraptor          | Liyasaurusaur        | 0.33
# linhevenator         | Liothrosaurusa       | 0.31
# lirainosaurus        | Limusasaurusaur      | 0.57
# liubangosaurus       | Likonchopteryxas     | 0.20
# loncosaurus          | Londosaurussa        | 0.75
# lophorhothon         | Longiantosauru       | 0.15
# lophostropheus       | Lomangolasaurusa     | 0.33
# loricatosaurus       | Lophochusaurusau     | 0.53
# losillasaurus        | Lorhodontopelta      | 0.14
# lourinhanosaurus     | Lophoyrodosaurusau   | 0.53
# lourinhasaurus       | Lotitasuchusauru     | 0.53
# luanchuanraptor      | Lusmanasaurusauru    | 0.38
# lufengosaurus        | Lukuithorrithoa      | 0.21
# luoyanggia           | Lubyangosaur         | 0.55
# lurdusaurus          | Lungaliasauru        | 0.50
# lusitanosaurus       | Lurdosaurusaurus     | 0.53
# lusotitan            | Luaetausaur          | 0.30
# lycorhinus           | Lypsaurusauv         | 0.36
# lythronax            | Lyceratopsi          | 0.30
# machairasaurus       | Manzhophodontosa     | 0.27
# macrogryphosaurus    | Mamosaurusaurustesa  | 0.44
# macrurosaurus        | Majunopatasauru      | 0.57
# magnamanus           | Masilophodon         | 0.18
# magnapaulia          | Majuansaurusa        | 0.42
# magnirostris         | Maeburusaurusa       | 0.38
# magnosaurus          | Macrosaurusau        | 0.67
# magulodon            | Marosaurusa          | 0.20
# magyarosaurus        | Malongosaurusau      | 0.64
# mahakala             | Manosaurus           | 0.22
# maiasaura            | Mayrosaurus          | 0.50
# majungasaurus        | Maeanosaurusaur      | 0.57
# malarguesaurus       | Makdedrosaurusau     | 0.53
# malawisaurus         | Macondosaurusa       | 0.54
# maleevus             | Marosaurus           | 0.33
# mamenchisaurus       | Magnopstesaurusa     | 0.53
# mandschurosaurus     | Manarasaurusaurusa   | 0.53
# manidens             | Makalolopa           | 0.11
# mantellisaurus       | Masakosaurusauru     | 0.47
# mantellodon          | Mantariasauru        | 0.25
# mapusaurus           | Macrodontusa         | 0.36
# marisaurus           | Manmisaurusa         | 0.73
# marshosaurus         | Manasaurusauru       | 0.54
# martharaptor         | Mardesauruskus       | 0.31
# masiakasaurus        | Marodontosaurus      | 0.50
# massospondylus       | Manfurosaurussuc     | 0.27
# matheronodon         | Manalosaurusau       | 0.15
# maxakalisaurus       | Macrolophustesau     | 0.33
# medusaceratops       | Metabiavosaurusa     | 0.27
# megacervixosaurus    | Menzhousaurusaurust  | 0.44
# megalosaurus         | Meyanasaurusau       | 0.62
# megaraptor           | Merospondysa         | 0.18
# mei                  | Megpu                | 0.25
# melanorosaurus       | Megacosaurusauru     | 0.60
# mendozasaurus        | Meyusaurusaurus      | 0.50
# mercuriceratops      | Megrarosaurustato    | 0.44
# merosaurus           | Menoceratops         | 0.36
# metriacanthosaurus   | Meravenatorasaurusau | 0.53
# microcephale         | Microsaurusaur       | 0.38
# microceratus         | Minzhomimusaur       | 0.31
# microcoelus          | Misgalosaurus        | 0.33
# microdontosaurus     | Microsaurusaurusau   | 0.59
# microhadrosaurus     | Migavosaurusaurusa   | 0.53
# micropachycephalosaurus | Microcachariaverasaurusau | 0.62
# microraptor          | Milociatorapt        | 0.58
# microvenator         | Microphodontho       | 0.54
# minmi                | Microph              | 0.17
# minotaurasaurus      | Mipporaptorsaurus    | 0.62
# miragaia             | Mirasaurus           | 0.44
# mirischia            | Microcerato          | 0.40
# moabosaurus          | Monisgosaurus        | 0.67
# mochlodon            | Monbarutita          | 0.20
# mojoceratops         | Morosaurusauru       | 0.31
# mongolosaurus        | Mochanthosaurus      | 0.64
# monkonosaurus        | Monoplasaurusau      | 0.64
# monoclonius          | Modexiaurosau        | 0.25
# monolophosaurus      | Moronosaurusaurus    | 0.56
# mononykus            | Mochagnisau          | 0.30
# montanoceratops      | Mochosaurusaurusa    | 0.31
# morelladon           | Morosaurusau         | 0.27
# morinosaurus         | Mognathophysim       | 0.08
# moros                | Morimod              | 0.33
# morrosaurus          | Mongyangosaur        | 0.50
# mosaiceratops        | Morosaurusaurus      | 0.43
# mussaurus            | Musilosauru          | 0.70
# muttaburrasaurus     | Muahuelosaurusauru   | 0.53
# muyelensaurus        | Mubiosaurusauru      | 0.50
# mymoorapelta         | Myngugopseltas       | 0.54
# naashoibitosaurus    | Nacrasaurusaurusaur  | 0.44
# nambalia             | Naneosauru           | 0.22
# nankangia            | Naraciasaur          | 0.40
# nanningosaurus       | Nantosaurausauru     | 0.60
# nanosaurus           | Nadycodontos         | 0.27
# nanotyrannus         | Naeosaurusauru       | 0.38
# nanshiungosaurus     | Nanshanodonusaurus   | 0.65
# nanuqsaurus          | Narganodontos        | 0.25
# nanyangosaurus       | Nasanoraxasaurus     | 0.60
# narambuenatitan      | Nasianosaurusauru    | 0.25
# nasutoceratops       | Narhaeosaurusaur     | 0.33
# nebulasaurus         | Nekovasaurusau       | 0.62
# nedcolbertia         | Neuquesaurusau       | 0.31
# nedoceratops         | Nekelisaurusau       | 0.31
# neimongosaurus       | Nedomosaurusauru     | 0.60
# nemegtomaia          | Nedospsaurusa        | 0.33
# nemegtonykus         | Neuquansaurusa       | 0.23
# nemegtosaurus        | Neoshanlongosau      | 0.43
# neosodon             | Neshanosau           | 0.33
# neovenator           | Neodontosaur         | 0.55
# neuquenraptor        | Nespondylusauru      | 0.29
# neuquensaurus        | Nedrognathusaur      | 0.43
# newtonsaurus         | Netycephalopu        | 0.31
# ngexisaurus          | Ngyunatitanti        | 0.25
# ngwevu               | Nguropsa             | 0.29
# nigersaurus          | Ningopeltasau        | 0.50
# ningyuansaurus       | Nianasaurusaurus     | 0.60
# niobrarasaurus       | Nischanosaurusau     | 0.53
# nipponosaurus        | Nignavusaurusau      | 0.50
# noasaurus            | Noshanosaur          | 0.60
# nodocephalosaurus    | Nodonosaurusaurusau  | 0.56
# nodosaurus           | Nothosaurusa         | 0.73
# nomingia             | Nosasaurus           | 0.22
# nopcsaspondylus      | Notranosaurusauru    | 0.38
# normanniasaurus      | Notraceratopsauru    | 0.56
# nothronychus         | Novonaxosaurus       | 0.38
# notoceratops         | Notosaurusauru       | 0.38
# notocolossus         | Nodosaurusauru       | 0.38
# notohypsilophodon    | Novocephalusaurusau  | 0.22
# nqwebasaurus         | Nquanurosaurus       | 0.54
# nurosaurus           | Nuanzhousaur         | 0.55
# nuthetes             | Nuriasauru           | 0.22
# nyasasaurus          | Nycerasaurusa        | 0.67
# ohmdenosaurus        | Ohicharosaurusa      | 0.57
# ojoceratops          | Ojonusaurusau        | 0.33
# ojoraptorsaurus      | Ojocanpusaurusaur    | 0.62
# olorotitan           | Oleropatlasa         | 0.45
# omeisaurus           | Omerosaurusa         | 0.73
# oohkotokia           | Ootiraptorsa         | 0.36
# opisthocoelicaudia   | Oppocacaraptoreitatu | 0.32
# oplosaurus           | Opariaptoran         | 0.18
# orcomimus            | Ornithomesu          | 0.40
# orkoraptor           | Orkosaurusau         | 0.45
# ornithodesmus        | Oraicaurusaurus      | 0.29
# ornitholestes        | Orchanosaurusau      | 0.21
# ornithomimoides      | Orcusaurusauruscu    | 0.12
# ornithomimus         | Orasaurusaurus       | 0.23
# ornithopsis          | Ordialosaurus        | 0.25
# orodromeus           | Ormanusaurus         | 0.36
# orthogoniosaurus     | Ornodontosaurusaur   | 0.59
# orthomerus           | Ordilousauru         | 0.27
# oryctodromeus        | Orthoabursaurus      | 0.36
# oshanosaurus         | Ostriavenators       | 0.15
# osmakasaurus         | Osmantosaurusa       | 0.69
# ostafrikasaurus      | Ostrophysisaurusa    | 0.62
# othnielia            | Otracatosau          | 0.20
# othnielosaurus       | Otaceratopsisaur     | 0.40
# otogosaurus          | Otoraptorsaur        | 0.58
# ouranosaurus         | Ouropaturannis       | 0.46
# overosaurus          | Ovocephaiauru        | 0.50
# oviraptor            | Ovoceratops          | 0.50
# owenodon             | Owasaurusa           | 0.11
# oxalaia              | Oxosaurus            | 0.25
# ozraptor             | Ozrakaanax           | 0.33
# pachycephalosaurus   | Pauropatoraptorsauru | 0.47
# pachyrhinosaurus     | Paerossaurustestes   | 0.53
# pachysuchus          | Patherosaurus        | 0.50
# padillasaurus        | Pardanosaurusau      | 0.64
# pakisaurus           | Paraptorapto         | 0.18
# palaeopteryx         | Pariosaurusaur       | 0.23
# palaeoscincus        | Parariatitanisa      | 0.21
# paludititan          | Paniraptorsau        | 0.17
# pampadromaeus        | Pashanasaurusau      | 0.36
# pamparaptor          | Parosaurusaur        | 0.33
# panamericansaurus    | Palamasausaurusauru  | 0.56
# panoplosaurus        | Paragniavosauru      | 0.57
# panphagia            | Palisauruss          | 0.20
# pantydraco           | Parcharaptor         | 0.36
# paralititan          | Paudiausaurus        | 0.17
# paranthodon          | Paraviasaurus        | 0.25
# pararhabdodon        | Parenosaurustes      | 0.29
# parasaurolophus      | Palaeosaurusaurus    | 0.50
# parksosaurus         | Parapalopausau       | 0.46
# paronychodon         | Palidesuasauru       | 0.15
# parvicursor          | Palasaurusaur        | 0.42
# patagonykus          | Parasaurustes        | 0.33
# patagosaurus         | Parshapusaurus       | 0.54
# pawpawsaurus         | Partagosaurusa       | 0.62
# pectinodon           | Pellenosauru         | 0.27
# pedopenna            | Pemalasau s          | 0.20
# pegomastax           | Penopeltasau         | 0.45
# peishansaurus        | Peinodontosauru      | 0.57
# pelecanimimus        | Petarisaurustes      | 0.36
# pellegrinisaurus     | Pecaterosaurustent   | 0.53
# peloroplites         | Perostenosauru       | 0.46
# pelorosaurus         | Perostexopsaur       | 0.54
# penelopognathus      | Pedopesaurusaur0s    | 0.31
# pentaceratops        | Pelosaurusaurus      | 0.36
# petrobrasaurus       | Pelliasaurusauru     | 0.53
# phaedrolosaurus      | Phorosaurusaurusa    | 0.56
# philovenator         | Phurosaurusaur       | 0.31
# phuwiangosaurus      | Photdolisaurusaur    | 0.50
# phuwiangvenator      | Phompschasauruscu    | 0.25
# phyllodon            | Phoeosaurus          | 0.30
# piatnitzkysaurus     | Pishanosaurusaurus   | 0.53
# pinacosaurus         | Pimaeosaurusau       | 0.69
# pitekunsaurus        | Pisaurusaurusau      | 0.50
# piveteausaurus       | Pikslosaurusauru     | 0.53
# planicoxa            | Platzkosaur          | 0.40
# plateosauravus       | Plotomasaurusaur     | 0.53
# plateosaurus         | Platikasaurusa       | 0.69
# platyceratops        | Plyocaraptorapt      | 0.50
# plesiohadros         | Planodontosaur       | 0.38
# pneumatoraptor       | Pnithosaurusauru     | 0.27
# podokesaurus         | Porochaeusauru       | 0.62
# poekilopleuron       | Pornosaurusisaur     | 0.27
# polacanthus          | Porodontosaur        | 0.33
# polyonax             | Poashalosa           | 0.44
# pradhania            | Procotitast          | 0.20
# prenocephale         | Probiosaurusau       | 0.23
# prenoceratops        | Procatoryptoria      | 0.50
# priconodon           | Proroceratop         | 0.09
# priodontognathus     | Prophaditasaurusau   | 0.24
# proa                 | Prorev               | 0.40
# probactrosaurus      | Protohasaurusauru    | 0.56
# proceratosaurus      | Prophosaurustesau    | 0.56
# procompsognathus     | Proelosaurusaurusa   | 0.41
# prodeinodon          | Propposaurusa        | 0.25
# propanoplosaurus     | Provenkosaurusauru   | 0.59
# proplanicoxa         | Prusaverdusaur       | 0.23
# prosaurolophus       | Prosodontosaurus     | 0.53
# protarchaeopteryx    | Proyocephalosaurusa  | 0.39
# protoavis            | Propalophys          | 0.40
# protoceratops        | Proselosaurusau      | 0.36
# protognathosaurus    | Prohadrousaurustest  | 0.50
# protohadros          | Protyrannosau        | 0.50
# psittacosaurus       | Pstehisaurusauru     | 0.53
# pteropelyx           | Ptromasaurus         | 0.27
# pterospondylus       | Ptaralosaurustus     | 0.40
# puertasaurus         | Pubumasaurusau       | 0.62
# pukyongosaurus       | Pustrysaurusauru     | 0.53
# pycnonemosaurus      | Pyrosaurusaurusdu    | 0.50
# pyroraptor           | Pycnoceratop         | 0.55
# qantassaurus         | Qanwulosaurusi       | 0.62
# qianzhousaurus       | Qianosaurusaurus     | 0.73
# qiaowanlong          | Qiabusaurusau        | 0.25
# qingxiusaurus        | Qiantrosaurusau      | 0.57
# qinlingosaurus       | Qianjiangosaurus     | 0.80
# qiupalong            | Qinliasauru          | 0.20
# quaesitosaurus       | Quengosaurusauru     | 0.60
# quetecsaurus         | Quburosaurusau       | 0.54
# quilmesaurus         | Qubbesaurusaur       | 0.62
# rahiolisaurus        | Rapatossusaurus      | 0.57
# rahonavis            | Rayisaurusa          | 0.30
# rajasaurus           | Rambosaurusa         | 0.64
# rapator              | Rantosaur            | 0.50
# rapetosaurus         | Ramiopsocerato       | 0.31
# raptorex             | Rapetopste           | 0.56
# ratchasimasaurus     | Rahichisaurasaurus   | 0.65
# rayososaurus         | Ranchasaurusau       | 0.54
# rebbachisaurus       | Reochaodontopter     | 0.33
# regnosaurus          | Rexiceratikis        | 0.17
# rhabdodon            | Rhhieniauru          | 0.10
# rhadinosaurus        | Rhuabalosaurusa      | 0.64
# rhoetosaurus         | Rhaxeranasauru       | 0.46
# riabininohadros      | Richiasaurusaurus    | 0.31
# richardoestesia      | Rianzhousaurusaur    | 0.12
# rinchenia            | Riahaxisaur          | 0.20
# rinconsaurus         | Rinhesaurusaur       | 0.62
# riojasaurus          | Richyposaurus        | 0.67
# rocasaurus           | Rochosaurusa         | 0.73
# ronaldoraptor        | Rordiasaurustes      | 0.29
# rubeosaurus          | Rubialovosaur        | 0.58
# ruehleia             | Ruantasaur           | 0.11
# rugops               | Rubesaur             | 0.14
# rukwatitan           | Ruanasaurusa         | 0.27
# ruyangosaurus        | Rubelosaurusaur      | 0.57
# sahaliyania          | Saurophosauru        | 0.17
# saichania            | Sauroidesiv          | 0.20
# saltasaurus          | Saurophosauru        | 0.50
# saltriovenator       | Saurophastestesa     | 0.13
# sanchusaurus         | Sauropaloysaur       | 0.46
# sangonghesaurus      | Saurususaurustesa    | 0.44
# sanjuansaurus        | Saurodosaurusau      | 0.57
# sanpasaurus          | Saurusterosau        | 0.42
# santanaraptor        | Sauropeltarapto      | 0.57
# sarahsaurus          | Sauroplosauru        | 0.58
# sarcolestes          | Saurustenosau        | 0.50
# sarcosaurus          | Saurolophuste        | 0.42
# sarmientosaurus      | Sanchopsaurustesa    | 0.56
# saturnalia           | Sauropsaurus         | 0.36
# saurolophus          | Sahypodontosa        | 0.17
# saurolophus          | Saurophodonto        | 0.50
# sauroniops           | Sauropsaurus         | 0.45
# sauropelta           | Saurophodont         | 0.55
# saurophaganax        | Santaraptorapto      | 0.21
# sauroplites          | Sarcosaurusau        | 0.42
# sauroposeidon        | Saurourasaurusa      | 0.36
# saurornithoides      | Sauropsalophodont    | 0.44
# saurornitholestes    | Sauropsaurusterrysa  | 0.44
# savannasaurus        | Sauroplesaurusm      | 0.50
# scansoriopteryx      | Scalasaurusaurusa    | 0.31
# scelidosaurus        | Scrurosaurusaur      | 0.57
# scipionyx            | Scanodontos          | 0.30
# sciurumimus          | Scinuqsaurusa        | 0.50
# scolosaurus          | Scapusaurusau        | 0.58
# scutellosaurus       | Scalosaurusaurus     | 0.60
# secernosaurus        | Sechasaurusauru      | 0.57
# segisaurus           | Seanosaurusa         | 0.64
# segnosaurus          | Setasaurusaur        | 0.58
# seitaad              | Sellalosa            | 0.25
# sellacoxa            | Seceratopst          | 0.10
# serendipaceratops    | Sepiventasaurusauru  | 0.33
# shamosaurus          | Shantadromeus        | 0.42
# shanag               | Shinodon             | 0.29
# shantungosaurus      | Shanosaurusaurusa    | 0.62
# shanxia              | Shanyuran            | 0.50
# shanyangosaurus      | Shanasaurusaurusa    | 0.62
# shaochilong          | Shantosaurusa        | 0.25
# shenzhousaurus       | Shantusaurusauru     | 0.60
# shidaisaurus         | Shantijosaurus       | 0.62
# shishugounykus       | Shanosaurusaurus     | 0.27
# shixinggia           | Shanasaurusa         | 0.18
# shuangmiaosaurus     | Shanodontosaurusau   | 0.59
# shunosaurus          | Shastaisaurus        | 0.58
# shuvuuia             | Shabusmasa           | 0.22
# siamodon             | Silisaurus           | 0.22
# siamosaurus          | Siverasaurusa        | 0.67
# siamotyrannus        | Sitankharosauru      | 0.36
# siamraptor           | Silamosaurus         | 0.36
# siats                | Silvero              | 0.17
# sigilmassasaurus     | Silasaurusaurusaur   | 0.53
# siluosaurus          | Sinchorosauru        | 0.58
# silvisaurus          | Sirasaurusaur        | 0.58
# similicaudipteryx    | Silaraptorsaurustes  | 0.33
# sinocalliopteryx     | Siomasatosaurusaur   | 0.24
# sinoceratops         | Silorasaurusau       | 0.38
# sinocoelurus         | Sisaurusaurusa       | 0.38
# sinopliosaurus       | Sishalosaurusaur     | 0.60
# sinornithoides       | Sianopeltasaurus     | 0.33
# sinornithomimus      | Siloniopaltasauru    | 0.38
# sinornithosaurus     | Silasaurusaurusaur   | 0.41
# sinosauropteryx      | Sitapeltarisaurus    | 0.31
# sinosaurus           | Silaisaurusa         | 0.64
# sinotyrannus         | Silophopeltara       | 0.38
# sinovenator          | Silopeltarapt        | 0.42
# sinraptor            | Signasaurus          | 0.20
# sinusonasus          | Sihkacephatus        | 0.25
# sirindhorna          | Silantosaurus        | 0.17
# skorpiovenator       | Skanosaurusaurus     | 0.27
# sonidosaurus         | Soshanosaurusa       | 0.69
# sonorasaurus         | Somanpesaurusa       | 0.62
# soriatitan           | Soriantholus         | 0.45
# sphaerotholus        | Sparthorasaurus      | 0.57
# spinophorosaurus     | Sprochilosaurusaur   | 0.53
# spinops              | Sparosaur            | 0.12
# spinosaurus          | Spukuasaurusa        | 0.58
# spinostropheus       | Spacrisaurusauru     | 0.27
# sps 100/44           | Sparosaurust         | 0.18
# staurikosaurus       | Stirasaurustisau     | 0.53
# stegoceras           | Staisaurusau         | 0.27
# stegopelta           | Stanisaurusa         | 0.18
# stegosaurides        | Stanyangopeltal      | 0.29
# stegosaurus          | Stracephalusa        | 0.33
# stegosaurus          | Strohaphusaur        | 0.50
# stenonychosaurus     | Stanosaurusauruste   | 0.53
# stenopelix           | Stanosaurusa         | 0.27
# stephanosaurus       | Stalosaurusaurus     | 0.60
# stokesosaurus        | Stanasaurusauru      | 0.50
# streptospondylus     | Stanosaurusaurusau   | 0.29
# struthiomimus        | Stenosaurusauru      | 0.29
# struthiosaurus       | Stantesaurusauru     | 0.53
# stygimoloch          | Standianosaur        | 0.08
# styracosaurus        | Starasaurusauru      | 0.64
# suchomimus           | Sutacephales         | 0.09
# suchosaurus          | Subisaurusaur        | 0.58
# sugiyamasaurus       | Suehuiusaurusaur     | 0.53
# sulaimanisaurus      | Suicatlasaurusmus    | 0.56
# supersaurus          | Surmimusuchus        | 0.33
# suskityrannus        | Sutheisaurusaur      | 0.29
# suuwassea            | Sunosaurusa          | 0.40
# suzhousaurus         | Surchusaurusau       | 0.69
# szechuanoraptor      | Szitatusaurusauru    | 0.25
# szechuanosaurus      | Szrohasaurusaurus    | 0.56
# talarurus            | Tachosaurus          | 0.60
# talenkauen           | Talophesauru         | 0.45
# talos                | Tacraur              | 0.17
# tambatitanis         | Talophysisauru       | 0.23
# tangvayosaurus       | Taotadrosaurusau     | 0.60
# tanius               | Tahasaur             | 0.29
# tanycolagreus        | Tahiovonixusaur      | 0.29
# tanystrosuchus       | Taoshanosaurusau     | 0.47
# taohelong            | Tarosaurusa          | 0.20
# tapuiasaurus         | Tartisaurusaur       | 0.62
# tarascosaurus        | Taroasaurusauru      | 0.64
# tarbosaurus          | Taroposaurusa        | 0.75
# tarchia              | Tarthosau            | 0.50
# tastavinsaurus       | Tallegnisaurusau     | 0.53
# tatankacephalus      | Taxalasaurusaurus    | 0.31
# tatankaceratops      | Tatyrosaurusaurus    | 0.38
# tataouinea           | Talongosauru         | 0.27
# tatisaurus           | Taospsaurusa         | 0.64
# taurovenator         | Tarchaeopterys       | 0.15
# taveirosaurus        | Talaphylophosau      | 0.36
# tawa                 | Taisau               | 0.40
# tazoudasaurus        | Tamuetannosauru      | 0.57
# tehuelchesaurus      | Tetrosaurusaurusa    | 0.44
# teinurosaurus        | Terosaurusaurus      | 0.64
# telmatosaurus        | Telliasaurusaur      | 0.64
# tendaguria           | Tecnobatorsu         | 0.18
# tengrisaurus         | Terosaurusauru       | 0.62
# tenontosaurus        | Tenchasaurusaur      | 0.57
# teratophoneus        | Teronosaurustis      | 0.43
# tethyshadros         | Terosaurusauru       | 0.31
# texacephale          | Teinonesaurus        | 0.17
# texasetes            | Teinosaurus          | 0.30
# thanos               | Thypsisa             | 0.29
# thecocoelurus        | Thuuladosaurusa      | 0.43
# thecodontosaurus     | Thavonsaurusaurusa   | 0.53
# thecospondylus       | Thaeosaurusaurus     | 0.40
# theiophytalia        | Thyphoraptoryxo      | 0.29
# therizinosaurus      | Thaekosaurusaurus    | 0.56
# therosaurus          | Thohadrosauru        | 0.67
# thescelosaurus       | Thasaocephalessa     | 0.33
# thespesius           | Thyrosaurusa         | 0.36
# thotobolosaurus      | Thaelosaurusaurus    | 0.56
# tianchisaurus        | Ticenatitaxusau      | 0.43
# tianyulong           | Tiolisaurusa         | 0.27
# tianyuraptor         | Tichtosaurusau       | 0.38
# tianzhenosaurus      | Tiplodontosaurusi    | 0.50
# tichosteus           | Tiladisaurus         | 0.36
# tienshanosaurus      | Tiraptoraptorsaur    | 0.44
# timimus              | Tihatiavi            | 0.38
# titanoceratops       | Titaiasaurusauru     | 0.33
# titanosaurus         | Tinzhosaurusau       | 0.69
# tochisaurus          | Toshanosaurus        | 0.67
# tonganosaurus        | Tomythosaurusau      | 0.57
# tonouchisaurus       | Tongyunggyangosa     | 0.33
# tornieria            | Toelosaurus          | 0.20
# torosaurus           | Torocaphosau         | 0.55
# torvosaurus          | Tonosaurusaur        | 0.67
# torvosaurus          | Tourosaurusau        | 0.75
# trachodon            | Tracodonusa          | 0.70
# tralkasaurus         | Tratosaurusaur       | 0.62
# traukutitan          | Trovenatorapt        | 0.33
# triceratops          | Trosisaurusau        | 0.33
# trigonosaurus        | Trachysaurustos      | 0.50
# trimucrodon          | Trachysaurusa        | 0.25
# trinisaura           | Trocatorasau         | 0.45
# troodon              | Trognathu            | 0.38
# tsaagan              | Tshandons            | 0.38
# tsagantegia          | Tscharodontos        | 0.33
# tsintaosaurus        | Tseoceratopsaur      | 0.43
# tugulusaurus         | Turysaurustesa       | 0.54
# tuojiangosaurus      | Tunurosaurusaurus    | 0.56
# turanoceratops       | Tuomaskanodontos     | 0.47
# turiasaurus          | Turnansaurusa        | 0.75
# tylocephale          | Tyellasaurus4        | 0.25
# tyrannosaurus        | Tyskanodontosau      | 0.57
# tyrannotitan         | Tyyangyptosaur       | 0.38
# uberabatitan         | Ubibosaurusaur       | 0.23
# udanoceratops        | Udinosaurusauru      | 0.36
# ultrasaurus          | Uloceratopsau        | 0.50
# unaysaurus           | Ungbuusaurus         | 0.64
# unenlagia            | Unchosaurus          | 0.10
# unescoceratops       | Ungkinisaurusaur     | 0.20
# unquillosaurus       | Unkylisaurusauru     | 0.53
# urbacodon            | Urusaurusau          | 0.30
# utahceratops         | Uthilophodonto       | 0.31
# utahraptor           | Uticanisauru         | 0.18
# uteodon              | Utasaurus            | 0.12
# vagaceratops         | Vacarasaurusau       | 0.38
# vahiny               | Vakasaur             | 0.14
# valdoraptor          | Vahisaurusaur        | 0.33
# valdosaurus          | Vaceraxapsaur        | 0.42
# vallibonavenatrix    | Varabaceratopstespu  | 0.33
# variraptor           | Vahyosaurusa         | 0.27
# vayuraptor           | Vaciasaurusa         | 0.36
# velafrons            | Venkerius0u          | 0.30
# velocipes            | Velosauru0t          | 0.40
# velociraptor         | Vembobatorapjo       | 0.46
# velocisaurus         | Venkanosauru0s       | 0.62
# venenosaurus         | Vespariatoca t       | 0.23
# veterupristisaurus   | Venwarchasaurasaur4u | 0.37
# vitakridrinda        | Viabiliasaurusa      | 0.29
# vitakrisaurus        | Vingsaurusaurus      | 0.50
# volkheimeria         | Vojosaurusauru       | 0.23
# vouivria             | Vovoasauru           | 0.44
# vulcanodon           | Vucedrosauru         | 0.27
# wakinosaurus         | Wanchesaurusau       | 0.62
# walgettosuchus       | Waralasaurusauru     | 0.40
# wamweracaudia        | Wamalasaurusaur      | 0.43
# wannanosaurus        | Warhinsaurusaur      | 0.57
# weewarrasaurus       | Werorasaurustasa     | 0.67
# wellnhoferia         | Wergasaurusaur       | 0.23
# willinakaqe          | Windusaurusau        | 0.33
# wintonotitan         | Wichyphodontos       | 0.31
# wuerhosaurus         | Wuemaesaurusau       | 0.62
# wulagasaurus         | Wudabursaurusa       | 0.62
# wulatelong           | Wullegrusaur         | 0.27
# xenoceratops         | Xeisaurusaurus       | 0.31
# xenoposeidon         | Xeuropstesmasp       | 0.38
# xenotarsosaurus      | Xesmatosaurusauru    | 0.56
# xianshanosaurus      | Xiansaurusaurusau    | 0.56
# xiaosaurus           | Xiangganosau         | 0.55
# xiaotingia           | Xiangodepmes         | 0.36
# xinjiangovenator     | Xicropteryxosaurus   | 0.18
# xinjiangtitan        | Xisatitanngikos      | 0.50
# xiongguanlong        | Xirariavosaurus      | 0.21
# xixianykus           | Xiangdusauru         | 0.45
# xixiasaurus          | Xiylongosauru        | 0.50
# xixiposaurus         | Xisopteryxocep       | 0.15
# xuanhanosaurus       | Xuabestesaurusau     | 0.53
# xuanhuaceratops      | Xuenosaurusaurusm    | 0.38
# xunmenglong          | Xundotasaurus        | 0.25
# xuwulong             | Xuaongosau           | 0.44
# yamaceratops         | Yaraptorsaurus       | 0.46
# yamanasaurus         | Yandosaurusaur       | 0.62
# yandusaurus          | Yachosaurusau        | 0.58
# yangchuanosaurus     | Yalakoraptorsaurus   | 0.53
# yaverlandia          | Yarosaurustes        | 0.17
# yibinosaurus         | Yinosaurusauru       | 0.69
# yimenosaurus         | Yishaxosaurusa       | 0.62
# yingshanosaurus      | Yiroplosaurustesa    | 0.50
# yinlong              | Yingurann            | 0.38
# yixianosaurus        | Yiderosaurusaur      | 0.57
# yizhousaurus         | Yiniraptorapto       | 0.23
# yongjinglong         | Yosaurusaurusa       | 0.08
# yuanmousaurus        | Yunopsandosauru      | 0.64
# yueosaurus           | Yucatoraptor         | 0.36
# yulong               | Yuranosa             | 0.29
# yunganglong          | Yudianisaurus        | 0.25
# yunnanosaurus        | Yurocatovusauru      | 0.57
# yunxianosaurus       | Yurotopsaurusaur     | 0.53
# yurgovuchia          | Yurosaurustes        | 0.33
# yutyrannus           | Yuavosaurusa         | 0.36
# zalmoxes             | Zarchaiauu           | 0.11
# zanabazar            | Zartarasaur          | 0.20
# zapalasaurus         | Zalisaurusauru       | 0.62
# zapsalis             | Zaratiavus           | 0.22
# zby                  | Zbosa                | 0.25
# zephyrosaurus        | Zerosaurusaurus      | 0.64
# zhanghenglong        | Zhundolopatasau      | 0.29
# zhejiangosaurus      | Zhodosaurusaurusa    | 0.50
# zhongornis           | Zhaobalisaur         | 0.36
# zhongyuansaurus      | Zherosaurusaurusa    | 0.50
# zhuchengceratops     | Zhorodontomimusaur   | 0.29
# zhuchengtyrannus     | Zhuwantinosaurusau   | 0.41
# ziapelta             | Ziosaurust           | 0.33
# zigongosaurus        | Zigarianthousau      | 0.43
# zizhongosaurus       | Zilaisaurustanos     | 0.47
# zuniceratops         | Zurriaceratops       | 0.77
# zuolong              | Zukypalti            | 0.25
# zupaysaurus          | Zuroplosaurus        | 0.67
# zuul                 | Zuroco               | 0.20
